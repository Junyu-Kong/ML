# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import joblib

sales_data = pd.read_csv('vgsales.csv')
cleaned_data = sales_data.dropna()
X = cleaned_data[ ['NA_Sales', 'EU_Sales', 'JP_Sales'] ]
y = cleaned_data[ ['Global_Sales'] ]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
model = LinearRegression()
model.fit(X_train, y_train)
joblib.dump(model, 'model.joblib')
# Out:
# ['model.joblib']

# %%
from sklearn.metrics import mean_squared_error

model = joblib.load('model.joblib')

predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
mse
# Out:
# 0.007089303035093109

# %%
import matplotlib.pyplot as plt
import numpy as np

predicted_regression_line = model.coef_[0, 0] * np.linspace(0, 30, num=100) + model.intercept_[0]

plt.scatter(X_test['NA_Sales'], predictions, color='blue', label='Predictions')
plt.scatter(X_test['NA_Sales'], y_test, color='green', label='Actual')
plt.plot(np.linspace(0, 30, num=100),regression_line, color='black', label='Predicted Regression Line')
plt.title('NA_Sales')
plt.legend()
plt.show()

# %%
predicted_regression_line = model.coef_[0, 1] * np.linspace(0, 10, num=100) + model.intercept_[0]

plt.scatter(X_test['EU_Sales'], predictions, color='yellow', label='Predictions')
plt.scatter(X_test['EU_Sales'], y_test, color='green', label='Actual')
plt.title('EU_Sales')
plt.plot(np.linspace(0, 10, num=100),regression_line, color='black', label='Predicted Regression Line')
plt.legend()
plt.show()

# %%
predicted_regression_line = model.coef_[0, 2] * np.linspace(0, 8, num=100) + model.intercept_[0]

plt.scatter(X_test['JP_Sales'], predictions, color='red', label='Predictions')
plt.scatter(X_test['JP_Sales'], y_test, color='green', label='Actual')
plt.title('JP_Sales')
plt.plot(np.linspace(0, 8, num=100),regression_line, color='black', label='Predicted Regression Line')
plt.legend()
plt.show()
